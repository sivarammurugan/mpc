# %%
u = np.random.rand(400)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(u)

# %%
u.size
# Out:
# 400

# %%
def puredelay(u,dt):
    y =[]
    y[:dt]=0
    y[dt+1:u.size-dt]
